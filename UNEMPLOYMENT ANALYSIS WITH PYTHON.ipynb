# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns",None)

import pandas as psql

# %%
Employment=pd.read_csv(r"C:\Users\`sree123\Downloads\Unemployment in India.csv",header=0)
Employment_bk=Employment.copy()
Employment.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
Employment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
Employment.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
Employment['Area'].value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
Employment=Employment.rename({' Date':'Date',' Frequency':'Frequency',' Estimated Unemployment Rate (%)':'Estimated_Unemployment_Rate_(%)',' Estimated Employed':'Estimated_Employed',' Estimated Labour Participation Rate (%)':'Estimated_Labour_Participation_Rate_(%)'}, axis=1)
Employment.head()
# Out:
#            Region         Date Frequency  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %%
Employment['Region'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
Employment.describe()
# Out:
#        Estimated_Unemployment_Rate_(%)  Estimated_Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated_Labour_Participation_Rate_(%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
Employment.shape
# Out:
# (768, 7)

# %%
Employment.head()
# Out:
#            Region         Date Frequency  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %%
Employment.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated_Unemployment_Rate_(%)',
#        'Estimated_Employed', 'Estimated_Labour_Participation_Rate_(%)',
#        'Area'],
#       dtype='object')

# %%
Employment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated_Unemployment_Rate_(%)          740 non-null    float64
#  4   Estimated_Employed                       740 non-null    float64
#  5   Estimated_Labour_Participation_Rate_(%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
Employment.describe().transpose()
# Out:
#                                          count          mean           std  \
# Estimated_Unemployment_Rate_(%)          740.0  1.178795e+01  1.072130e+01
# Estimated_Employed                       740.0  7.204460e+06  8.087988e+06
# Estimated_Labour_Participation_Rate_(%)  740.0  4.263012e+01  8.111094e+00
#
#                                               min           25%         50%  \
# Estimated_Unemployment_Rate_(%)              0.00  4.657500e+00        8.35
# Estimated_Employed                       49420.00  1.190404e+06  4744178.50
# Estimated_Labour_Participation_Rate_(%)     13.33  3.806250e+01       41.16
#
#                                                   75%          max
# Estimated_Unemployment_Rate_(%)          1.588750e+01        76.74
# Estimated_Employed                       1.127549e+07  45777509.00
# Estimated_Labour_Participation_Rate_(%)  4.550500e+01        72.57

# %%
Employment_dup=Employment[Employment.duplicated(keep='last')]
Employment_dup
# Out:
#     Region Date Frequency  Estimated_Unemployment_Rate_(%)  \
# 359    NaN  NaN       NaN                              NaN
# 360    NaN  NaN       NaN                              NaN
# 361    NaN  NaN       NaN                              NaN
# 362    NaN  NaN       NaN                              NaN
# 363    NaN  NaN       NaN                              NaN
# 364    NaN  NaN       NaN                              NaN
# 365    NaN  NaN       NaN                              NaN
# 366    NaN  NaN       NaN                              NaN
# 367    NaN  NaN       NaN                              NaN
# 368    NaN  NaN       NaN                              NaN
# 369    NaN  NaN       NaN                              NaN
# 370    NaN  NaN       NaN                              NaN
# 371    NaN  NaN       NaN                              NaN
# 372    NaN  NaN       NaN                              NaN
# 754    NaN  NaN       NaN                              NaN
# ...

# %%
Employment=Employment.dropna()

# %%
Employment.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated_Unemployment_Rate_(%)            0
# Estimated_Employed                         0
# Estimated_Labour_Participation_Rate_(%)    0
# Area                                       0
# dtype: int64

# %%
Employment['Date']=pd.to_datetime(Employment['Date'])

# %%
Employment['year']=pd.DatetimeIndex(Employment['Date']).year
Employment['month']=pd.DatetimeIndex(Employment['Date']).month
Employment['day']=pd.DatetimeIndex(Employment['Date']).day
Employment.head()
# Out:
#            Region       Date Frequency  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# 2          12086707.0                                    43.50  Rural  2019
# 3          12285693.0                                    43.97  Rural  2019
# 4          12256762.0                                    44.68  Rural  2019
#
#    month  day
# 0      5   31
# 1      6   30
# 2      7   31
# ...

# %%
del Employment['Frequency']

# %%
Employment.shape
# Out:
# (740, 9)

# %%
Employment.head()
# Out:
#            Region       Date  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# 2          12086707.0                                    43.50  Rural  2019
# 3          12285693.0                                    43.97  Rural  2019
# 4          12256762.0                                    44.68  Rural  2019
#
#    month  day
# 0      5   31
# 1      6   30
# 2      7   31
# 3      8   31
# 4      9   30

# %%
Employment.columns
# Out:
# Index(['Region', 'Date', 'Estimated_Unemployment_Rate_(%)',
#        'Estimated_Employed', 'Estimated_Labour_Participation_Rate_(%)', 'Area',
#        'year', 'month', 'day'],
#       dtype='object')

# %%
#coorelation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(Employment.corr(),annot=True,cmap='Blues_r')
# Out:
# <Axes: >

# %%
Employment.Area.value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
Employment.Area.value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
sns.countplot(x='Area',data=Employment,palette=['blue','orange'])
# Out:
# <Axes: xlabel='Area', ylabel='count'>

# %%
Employment.Region.value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
sns.countplot(y='Region',data=Employment)
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %%
plt.title('Unemployment Rate based on Area')
sns.scatterplot(y=Employment['Region'],x=Employment['Estimated_Unemployment_Rate_(%)'],hue=Employment['Area'])
# Out:
# <Axes: title={'center': 'Unemployment Rate based on Area'}, xlabel='Estimated_Unemployment_Rate_(%)', ylabel='Region'>
